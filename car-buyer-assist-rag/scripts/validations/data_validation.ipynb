# %%
# !pip install google-genai

# %%
import chromadb

# %%
client = chromadb.PersistentClient("../../chroma_db")

# %%
client.list_collections()
# Out:
# [Collection(name=toyota_specs), Collection(name=migration_test)]

# %%
from dotenv import load_dotenv

# %%
load_dotenv("../../.env")
# Out:
# True

# %%
from chromadb.utils.embedding_functions import GoogleGenaiEmbeddingFunction

# %%
google_ef = GoogleGenaiEmbeddingFunction(
    model_name="models/text-embedding-004"
)

# %%
toyota_specs = client.get_collection(
    name="toyota_specs"
)

# %%
toyota_specs.count()
# Out:
# 32

# %%
query_text = "What is the fuel efficiency of the Camry hybrid?"

# %%
query_vector = google_ef([query_text])[0]

# %%
results = toyota_specs.query(
    query_embeddings=[query_vector],
    n_results=5
)

# %%
results
# Out:
# {'ids': [['731620ad-755c-41c4-9d7c-0be592babfd5',
#    'e842a974-65cc-4ad5-93e6-277c79a4e2a7',
#    '954feb78-8952-434b-ae1f-6361b3638f04',
#    'acf64b7a-ec9f-4688-a830-e29b66339f59',
#    '9a35aeae-c001-4605-a790-53889c2659e3']],
#  'embeddings': None,
#  'documents': [['Key Features\nSafety\nToyota Safety Sense (TSS) 2.5+, which includes:\nPre-Collision System with Pedestrian Detection\nLane Departure Alert with Steering Assist\nAdaptive Cruise Control\nRoad Sign Assist and Lane Tracing Assist\nComfort and Technology\n7-inch or optional 9-inch touchscreen infotainment system\nApple CarPlay, Android Auto, and Amazon Alexa compatibility\nOptional panoramic sunroof and leather-trimmed seats\nHeads-up display and wireless charging\nDesign\nSleek, aerodynamic styling with LED headlights\nSporty trims like SE and XSE with an available two-tone roof\nFuel Efﬁciency\nGasoline Engine: ~28 MPG (city) / ~39 MPG (highway)\nHybrid Powertrain: ~51 MPG (city) / ~53 MPG (highway)\nCamry’s hybrid option stands out for its fuel economy in the midsize sedan segment.\nPricing\nBase Model (LE): Starting at $26,000\nMid-Level Trim (SE): Starting at $28,000\nPremium Trim (XSE V6): Starting at $36,000\nHybrid Variants: Starting at $29,000\nIdeal Customer',
#    'Sales Strategies\nEmphasize Hybrid Efﬁciency: Perfect for buyers looking to save on fuel costs\nHighlight Safety Features: A key selling point for families and professionals\nLeverage Test Drives: Showcase the smooth ride and premium interiors\nFAQs\nDoes the Toyota Camry come with AWD?\nNo, the Camry is available in FWD (Front-Wheel Drive) only\nWhat is the warranty for the Toyota Camry?\n3 years/36,000 miles basic warranty and 5 years/60,000 miles powertrain warranty\nQuick Reference Cheat Sheet\nFeature Gasoline Models Hybrid Models\nEngine Output (HP) 203 (2.5L), 301 (V6) 208 (combined)\nTransmission 8-speed automatic eCVT\nFuel Efﬁciency (MPG) 28/39 51/53\nStarting Price (USD) $26,000 $29,000',
#    'rag/Toyota_Camry_Specifications.md\nToyota Camry: The Sophisticated Midsize Sedan\nOverview\nThe Toyota Camry is a premium midsize sedan renowned for its reliability, spacious interiors, and smooth performance. It caters to\nprofessionals, small families, and those seeking a balance of luxury and efﬁciency, with hybrid options available for eco-conscious buyers.\nEngine Options\n2.5L 4-Cylinder Gasoline Engine\nPower Output: 203 HP\nTransmission: 8-speed automatic\nKey Feature: Efﬁcient and reﬁned performance for everyday driving\n3.5L V6 Gasoline Engine (Optional)\nPower Output: 301 HP\nTransmission: 8-speed automatic\nKey Feature: Delivers a sporty and dynamic driving experience\nHybrid Powertrain\nPower Output: 208 HP (combined)\nTransmission: Electronically Controlled CVT (eCVT)\nKey Feature: Exceptional fuel efﬁciency with reduced emissions\nKey Features\nSafety\nToyota Safety Sense (TSS) 2.5+, which includes:\nPre-Collision System with Pedestrian Detection\nLane Departure Alert with Steering Assist',
#    'Pricing\nBase Model (LE): Starting at $26,000\nMid-Level Trim (SE): Starting at $28,000\nPremium Trim (XSE V6): Starting at $36,000\nHybrid Variants: Starting at $29,000\nIdeal Customer\nProfessionals: Modern interiors and advanced tech for a sophisticated experience\nEco-Conscious Buyers: Hybrid models with outstanding fuel efﬁciency\nSmall Families: Ample legroom, safety features, and reliability for daily use\nCompetitor Comparison\nToyota Camry vs. Honda Accord\nCamry offers a V6 engine option for performance enthusiasts, while Accord focuses on turbocharged engines\nCamry hybrid models provide better fuel efﬁciency\nToyota Camry vs. Nissan Altima\nCamry offers superior safety features and a sportier design\nAltima boasts optional AWD, which is unavailable in Camry\nSales Strategies\nEmphasize Hybrid Efﬁciency: Perfect for buyers looking to save on fuel costs\nHighlight Safety Features: A key selling point for families and professionals',
#    'Transmission: eCVT\nKey Feature: Electric-only range of ~42 miles, ideal for urban commutes\nKey Features\nSafety\nToyota Safety Sense (TSS) 2.5:\nPre-Collision System with Pedestrian Detection\nLane Departure Alert with Steering Assist\nFull-Speed Range Dynamic Radar Cruise Control\nLane Tracing Assist\nComfort and Technology\n8-inch or optional 10.5-inch touchscreen infotainment system\nWireless Apple CarPlay and Android Auto compatibility\nAvailable digital rearview mirror\nHeated and ventilated front seats\nDesign\nBold, aggressive styling with available two-tone exterior color options\nLED headlights and taillights\nHands-free power liftgate\nFuel Efﬁciency\nGasoline Engine: ~27 MPG (city) / ~35 MPG (highway)\nHybrid Powertrain (HEV): ~41 MPG (city) / ~38 MPG (highway)\nPlug-in Hybrid (Prime): ~94 MPGe (electric + hybrid) / ~42 miles all-electric range\nPricing\nBase Model (LE): Starting at $28,000\nMid-Level Trim (XLE): Starting at $30,000\nPremium Trim (Limited): Starting at $36,000']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'total_pages': 1,
#     'moddate': "D:20241230030017Z00'00'",
#     'creationdate': "D:20241230030017Z00'00'",
#     'page': 0,
#     'producer': 'macOS Version 15.2 (Build 24C101) Quartz PDFContext',
#     'chunk_index': 1,
#     'source': 'Toyota_Camry_Specifications.pdf',
#     'page_label': '1',
#     'model_name': 'Camry',
#     'creator': 'PyPDF'},
#    {'page': 0,
#     'creationdate': "D:20241230030017Z00'00'",
#     'chunk_index': 3,
#     'page_label': '1',
#     'source': 'Toyota_Camry_Specifications.pdf',
#     'creator': 'PyPDF',
#     'total_pages': 1,
#     'model_name': 'Camry',
#     'moddate': "D:20241230030017Z00'00'",
#     'producer': 'macOS Version 15.2 (Build 24C101) Quartz PDFContext'},
#    {'page': 0,
#     'creator': 'PyPDF',
#     'producer': 'macOS Version 15.2 (Build 24C101) Quartz PDFContext',
#     'moddate': "D:20241230030017Z00'00'",
#     'model_name': 'Camry',
#     'total_pages': 1,
#     'chunk_index': 0,
#     'page_label': '1',
#     'source': 'Toyota_Camry_Specifications.pdf',
#     'creationdate': "D:20241230030017Z00'00'"},
#    {'source': 'Toyota_Camry_Specifications.pdf',
#     'chunk_index': 2,
#     'moddate': "D:20241230030017Z00'00'",
#     'total_pages': 1,
#     'page_label': '1',
#     'creationdate': "D:20241230030017Z00'00'",
#     'page': 0,
#     'model_name': 'Camry',
#     'creator': 'PyPDF',
#     'producer': 'macOS Version 15.2 (Build 24C101) Quartz PDFContext'},
#    {'creationdate': "D:20241230025924Z00'00'",
#     'moddate': "D:20241230025924Z00'00'",
#     'producer': 'macOS Version 15.2 (Build 24C101) Quartz PDFContext',
#     'page_label': '1',
#     'creator': 'PyPDF',
#     'page': 0,
#     'total_pages': 1,
#     'chunk_index': 1,
#     'model_name': 'RAV4',
#     'source': 'Toyota_RAV4_Specifications.pdf'}]],
#  'distances': [[0.5831044912338257,
#    0.6088320016860962,
#    0.6379958391189575,
#    0.6389936208724976,
#    0.6719971895217896]]}

# %%
print(query_text)
print("-"*100)
for i in range(len(results["ids"][0])):
    print(f"Distance: {results['distances'][0][i]}")
    print(f"ID: {results['ids'][0][i]}")
    print(f"Model: {results['metadatas'][0][i]['model_name']}")
    # print(f"Document: {results['documents'][0][i]}")
    print("-"*100)

# %%
results =toyota_specs.query(
    query_texts=[query_text],
    n_results=5
)

# %%
# Queries
queries = [
    "What is the fuel efficiency of the Camry hybrid?",
    "Which sedan is better for first-time buyers?",
    "Is AWD available on the Camry?",
    "What is the starting price of the Corolla?",
    "I need a fuel-efficient car for city driving, what do you recommend?",
    "Can you schedule a test drive for me?"
]

# %%
EMBEDDING_MODEL_NAME = "text-embedding-004"

# %%
from dotenv import load_dotenv

# %%
load_dotenv("../../.env")

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# %%
embeddings = GoogleGenerativeAIEmbeddings(model=EMBEDDING_MODEL_NAME) # Specify your model

# %%
from langchain_chroma import Chroma

# %%
vector_store = Chroma(
    collection_name="toyota_specs",
    embedding_function=embeddings,
    persist_directory="../../chroma_db"
)

# %%
queries[0]

# %%
results = vector_store.similarity_search(queries[0], k=5)

# %%
results

# %%
document = results[0]

# %%
document.id

# %%
document.metadata

# %%
document.metadata['source']

# %%
document.metadata['model_name']

# %%
document.page_content

# %%
print(queries[0])
print("-"*100)
for idx, document in enumerate(results, 1):
    print(f"Document {idx}:")
    print("-"*100)
    print(document.page_content)
    print("-"*100)
    metadata = document.metadata
    print(f"{metadata['source']} - {metadata['page']} - {metadata['chunk_index']} - {metadata['model_name']}")
    print("-"*100)

# %%
queries[0]

# %%
results_with_scores = vector_store.similarity_search_with_score(queries[0], k=5)

# %%
results_with_scores

# %%
document_with_score = results_with_scores[0]

# %%
document_with_score[0]

# %%
document_with_score[0].metadata

# %%
document_with_score[0].page_content

# %%
document_with_score[1]

# %%
print(queries[0])
print("-"*100)
for doc, score in results_with_scores:
    print(f"Score: {score} | Source: {doc.metadata['source']} | Content: {doc.page_content}")
    print("-"*100)

# %%
def get_toyota_specs(query):
    results = vector_store.similarity_search(query, k=5)
    print(query)
    print("-"*100)
    for idx, result in enumerate(results):
        print(f"Result {idx+1}:")
        print("-"*100)
        print(result.page_content[:200])
        print("-"*100)
        metadata = result.metadata
        print(f"{metadata['source']} - {metadata['page']} - {metadata['chunk_index']} - {metadata['model_name']}")
        print("-"*100)

# %%
def get_toyota_specs_with_scores(query):
    results_with_scores = vector_store.similarity_search_with_score(query, k=5)
    print(query)
    print("-"*100)
    for doc, score in results_with_scores:
        print(f"Score: {score} | Source: {doc.metadata['source']} | Content: {doc.page_content[:200]}")
        print("-"*100)

# %%
queries[1]

# %%
get_toyota_specs(queries[1])

# %%
get_toyota_specs_with_scores(queries[1])

# %%
queries[5]

# %%
get_toyota_specs(queries[5])

# %%
get_toyota_specs_with_scores(queries[5])
