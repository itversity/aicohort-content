# %% [raw]
# # JSON Example
# {
#     "model": "Toyota Corolla",
#     "year": 2024,
#     "price": 22000
# }

# %% [raw]
# # Toyota Camry JSON for Data Types
#
# {
#     "model": "Toyota Camry",
#     "year": 2024,
#     "price": 28000,
#     "is_hybrid": true,
#     "discontinued_date": null,
#     "colors": ["White", "Black", "Silver"],
#     "engine": {
#         "type": "2.5L 4-Cylinder",
#         "horsepower": 203
#     }
# }

# %% [raw]
# # Real-World Structure
#
# {
#     "model": "Toyota RAV4",
#     "type": "SUV",
#     "variants": [
#         {
#             "name": "Gasoline",
#             "horsepower": 203,
#             "price": 28000
#         },
#         {
#             "name": "Hybrid",
#             "horsepower": 219,
#             "price": 30000
#         }
#     ],
#     "features": ["Safety Sense", "Apple CarPlay", "AWD"]
# }
