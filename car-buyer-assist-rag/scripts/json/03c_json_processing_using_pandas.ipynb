# %%
import pandas as pd

# %%
pd.read_json("row_format.jsonl", lines=True)
# Out:
#      model   type  price
# 0  Corolla  Sedan  22000
# 1     RAV4    SUV  28000
# 2    Camry  Sedan  26000

# %%
df = pd.read_json("row_format.jsonl", lines=True)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['model', 'type', 'price'], dtype='object')

# %%
df[["model", "price"]]
# Out:
#      model  price
# 0  Corolla  22000
# 1     RAV4  28000
# 2    Camry  26000

# %%
pd.read_json("column_format.json")
# Out:
#      model   type  price
# 0  Corolla  Sedan  22000
# 1     RAV4    SUV  28000
# 2    Camry  Sedan  26000

# %%
df
# Out:
#      model   type  price
# 0  Corolla  Sedan  22000
# 1     RAV4    SUV  28000
# 2    Camry  Sedan  26000

# %%
df.to_dict()
# Out:
# {'model': {0: 'Corolla', 1: 'RAV4', 2: 'Camry'},
#  'type': {0: 'Sedan', 1: 'SUV', 2: 'Sedan'},
#  'price': {0: 22000, 1: 28000, 2: 26000}}

# %%
df.to_dict(orient="records")
# Out:
# [{'model': 'Corolla', 'type': 'Sedan', 'price': 22000},
#  {'model': 'RAV4', 'type': 'SUV', 'price': 28000},
#  {'model': 'Camry', 'type': 'Sedan', 'price': 26000}]
